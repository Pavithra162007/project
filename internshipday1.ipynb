# %%
name="Pavithra"
age=19
CGPA=8.5
placed=True
print("Student name:",name)
print("Age:",age)
print("CGPA:",CGPA)
print("Placed:",placed)
print(type(name))
print(type(age))
print(type(CGPA))
print(type(placed))
# Out:
# Student name: Pavithra
# Age: 19
# CGPA: 8.5
# Placed: True
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
